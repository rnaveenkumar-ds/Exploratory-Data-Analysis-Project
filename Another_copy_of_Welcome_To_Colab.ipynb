# %% [markdown]
# <a href="https://colab.research.google.com/github/rnaveenkumar-ds/Exploratory-Data-Analysis-Project/blob/main/Another_copy_of_Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Welcome to Colab!

# %%
#Load DataSet
import pandas as pd
url = ("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
df = pd.read_csv(url)
print("original dataset \n",df)
# Out:
# original dataset
#       PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
#inspect data
print(df.info())
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# None
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# ...

# %%
#Handling Missing Values
df["Age"] = df["Age"].fillna(df["Age"].mean())
df["PassengerId"] = df["PassengerId"].fillna(df["PassengerId"].mode()[0])
print("dataset after filling missing values \n",df["Age"])
print("dataset after filling missing values \n",df["PassengerId"])
# Out:
# dataset after filling missing values
#  0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.699118
# 889    26.000000
# 890    32.000000
# Name: Age, Length: 891, dtype: float64
# dataset after filling missing values
#  0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 886    887
# 887    888
# 888    889
# 889    890
# 890    891
# Name: PassengerId, Length: 891, dtype: int64

# %%
#Remove Duplicates
df=df.drop_duplicates()

# %%
#Filter Data:Passangers in second class
df_second_class = df[df["PassengerId"] >= 4]
print("filtering the second class passangers list: \n",df_second_class)
# Out:
# filtering the second class passangers list:
#       PassengerId  Survived  Pclass  \
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                              Name     Sex        Age  SibSp  \
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000      1
# 4                        Allen, Mr. William Henry    male  35.000000      0
# 5                                Moran, Mr. James    male  29.699118      0
# 6                         McCarthy, Mr. Timothy J    male  54.000000      0
# 7                  Palsson, Master. Gosta Leonard    male   2.000000      3
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
#line plot:survival rate
survival_rate =df.groupby("Pclass")["Survived"].mean()
survival_rate.plot(kind="line",color="skyblue")
plt.title("Survival Rate by Passenger Class")
plt.xlabel("Passenger Class")
plt.ylabel("Survival Rate")
plt.show()

# %%
#bar chat:survival rate
survival_rate =df.groupby("Pclass")["Survived"].mean()
survival_rate.plot(kind="bar",color="green")
plt.title("Survival Rate by Passenger Class")
plt.xlabel("Passenger Class")
plt.ylabel("Survival Rate")
plt.show()

# %%
#Histplot for Age
sns.histplot(df["Age"],color="orange",kde=True,edgecolor="green")
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()

# %%
#Scatter plot: Age vs Fare
plt.scatter(df["Age"],df["Fare"],color="purple",marker="o",alpha=0.7)
plt.title("Age vs Fare")
plt.xlabel("Age")
plt.ylabel("Fare")
plt.show()

# %% [markdown]
# # **Key Insights from Exploratory Data Analysis (EDA)**
# # Dataset Overview
#
# * The dataset has information about 891 passengers. This information is made up of 12 things about each passenger including numbers and categories. The dataset contains 12 features, about these 891 passengers.
#
# * The Target variable Survived is a thing, which makes it perfect, for classification analysis. We are looking at the Target variable Survived to see how it can be used for classification. The Target variable Survived is what we want to focus on.
#
# # Data Quality & Preprocessing
#
# **Missing values found in:**
#
# * The age was missing for some people so it was filled in with the age, which is about 29.7 years old. There were 177 ages that needed to be filled in.
#
# * The Cabin thing is really incomplete, with a lot of missing information it only has 204 that're actually there.
# * No duplicate records after cleaning.
#
# # Survival Analysis by Passenger Class
#
# * People who travel in class have the best chance of staying alive. The first class passengers are the ones who usually survive.
#
# * The people who travel in the class have the lowest survival rate when it comes to the 3rd class passengers. They are the ones who're most likely to not make it. The 3rd class passengers do not do well.
#
# * The class of the passenger has an effect on whether they survive or not. The passenger class is very important when it comes to survival chances. If you are a passenger the passenger class you are, in can make a difference.
#
# # Age Distribution
#
# * Majority of passengers are between 20–40 years.
#
# * Age distribution is slightly right-skewed.
#
# * When it comes to surviving, children and younger passengers do a lot better than others. Children and younger passengers have a chance of making it through because they are children and younger passengers. This is really news, for children and younger passengers.
#
# # Fare Insights
#
# * The way fares are spread out is really uneven. You will find some fares that're extremely high which is not normal. These extreme fares are very different, from the others. They affect the overall distribution of fares. Fares are not balanced all.
#
# * People who paid more for their tickets, on the ship usually had a chance of staying alive. The passengers who paid fares generally had better survival chances.
#
# * The fare that you pay is really connected to the kind of passenger class you're, in. When we talk about fare it is closely related to passenger class. The type of passenger class you choose will affect the fare that you have to pay.
#
# #Age vs Fare Relationship
#
# * The scatter plot does not show a connection, between the age of a person and the fare they pay.
#
# * The age and the fare do not seem to be related in a way.
#
# * When you look at the scatter plot you can see that the age and the fare do not have a linear relationship.
#
# * The cost of tickets is really high when the passengers are young and they want to travel in a class. People think that high fares are mostly for passengers who want to travel in a higher class. When you look at the prices you can see that high fares are often for classes and, for people who are not very old.
#
# * Final The Titanic was a ship that sank. Survival on the Titanic really depended on what kind of ticket you had how much you paid for it and how old you were. If you were a passenger, on the Titanic these things were very important. The kind of ticket you had the fare you paid and your age were the things that decided if you would survive or not.
#
# * Proper preprocessing is really important because it makes the dataset ready, for the model. When we have a dataset the model can work with it. Proper preprocessing makes the dataset model-ready. It is a very crucial step.
#
# * EDA reveals clear patterns useful for machine learning classification models.
